# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
dir_ = "DATA/"
day_1 = xr.open_dataset(dir_ + 'roms_bobhires_avg_0001.nc')

# %%
ds=xr.open_dataset(dir_ + 'roms_bobhires_avg_0001.nc').temp.values

lo=xr.open_dataset(dir_ + 'roms_bobhires_avg_0001.nc').lon_rho.values

la=xr.open_dataset(dir_ + 'roms_bobhires_avg_0001.nc').lat_rho.values

lo=lo[0]

la=la[:,1]

plt.pcolor(lo,la,ds[0,-1])

# %%
us  = xr.open_dataset(dir_ + 'roms_bobhires_avg_0001.nc').mask_u.values

# %%
day_1
# Out:
# <xarray.Dataset>
# Dimensions:        (tracer: 2, boundary: 4, s_rho: 40, s_w: 41, eta_rho: 1887,
#                     xi_rho: 2113, eta_u: 1887, xi_u: 2112, eta_v: 1886,
#                     xi_v: 2113, eta_psi: 1886, xi_psi: 2112, ocean_time: 1)
# Coordinates:
#   * s_rho          (s_rho) float64 -0.9875 -0.9625 -0.9375 ... -0.0375 -0.0125
#   * s_w            (s_w) float64 -1.0 -0.975 -0.95 -0.925 ... -0.05 -0.025 0.0
#     lon_rho        (eta_rho, xi_rho) float64 ...
#     lat_rho        (eta_rho, xi_rho) float64 ...
#     lon_u          (eta_u, xi_u) float64 ...
#     lat_u          (eta_u, xi_u) float64 ...
#     lon_v          (eta_v, xi_v) float64 ...
#     lat_v          (eta_v, xi_v) float64 ...
#     lon_psi        (eta_psi, xi_psi) float64 ...
#     lat_psi        (eta_psi, xi_psi) float64 ...
#   * ocean_time     (ocean_time) datetime64[ns] 2012-01-02T12:00:00
# Dimensions without coordinates: tracer, boundary, eta_rho, xi_rho, eta_u, xi_u,
# ...

# %%
lon_min=40; lon_max=100.; lat_min=-20. ; lat_max=25.

lat_ = ds['latitude']

lon_ = ds['longitude']

tracknumber=192
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 lon_min=40; lon_max=100.; lat_min=-20. ; lat_max=25.
# ----> 3 lat_ = ds['latitude']
#       5 lon_ = ds['longitude']
#       7 tracknumber=192
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
